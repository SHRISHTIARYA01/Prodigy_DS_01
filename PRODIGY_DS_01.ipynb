# %% [markdown]
# <a href="https://colab.research.google.com/github/SHRISHTIARYA01/Prodigy_DS_01/blob/main/PRODIGY_DS_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# NO DATA SET IS TAKEN.

# %% [markdown]
# DATA SET TAKEN FROM KAGGLE

# %% [markdown]
# Gender_Classification_Dataset

# %% [markdown]
# new

# %% [markdown]
# NO DATA SET IS TAKEN.
#
# DATA SET TAKEN FROM KAGGLE
#
# Gender_Classification_Dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample dataset
data = {
    "Gender": [
        "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female",
        "Male", "Female", "Male", "Female", "Male", "Female", "Male",
        "Male", "Female", "Male","Male",
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Set style
sns.set(style="whitegrid")

# Create bar plot
plt.figure(figsize=(6, 4))
sns.countplot(x="Gender", data=df, palette="Set2")

# Add titles and labels
plt.title("Gender Distribution in Sample Population")
plt.xlabel("Gender")
plt.ylabel("Count")

# Show plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-13-02cccca7b210>:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Gender", data=df, palette="Set2")

# %%
# Step 1: Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 2: Load the uploaded dataset
# Make sure you uploaded the voice.csv file to Colab
df = pd.read_csv('voice.csv')

# Step 3: View the first few rows (optional)
df.head()

# Step 4: Plot the gender distribution
plt.figure(figsize=(6, 4))
sns.countplot(x='label', data=df, palette='Set2')
plt.title('Gender Distribution in Voice Dataset')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-14-421e355d0ad3>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='label', data=df, palette='Set2')
